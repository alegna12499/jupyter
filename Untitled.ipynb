# %% [markdown]
# Here is a simple example of a Jupyter Notebook.

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
a = 10
b = 35 
print(a + b)
# Out:
# 45

# %%
from matplotlib import pyplot as plt

x = [5, 8, 10]
y = [12, 16, 6]

plt.plot(x,y)

plt.title("Epic Info")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")

plt.show()
